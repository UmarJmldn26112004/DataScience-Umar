# %%
print("[SOAL1]")
Bur = 6
Piz = 3
Dim = 4
Ekk = 4
Mil = 2
Esk = 5

total = Bur + Piz + Dim + Ekk + Mil + Esk
jumlah = (Bur * 24000) +  (Piz * 52000) + (Dim * 30000) + (Ekk * 7500 ) + (Mil * 10000) + (Esk * 15000)
print("total makanan yang dipesan : " + str(total))
print("harga jumlah keseluruhan : " + str(jumlah))
 
print("")
print("[SOAL2]")
pn_bur = Bur / 24
print("harga jumlah persentase nya : " + str(pn_bur))
pn_piz = Piz / 24
print("harga jumlah persentase nya : " + str(pn_piz))
pn_dim = Dim / 24
print("harga jumlah persentase nya : " + str(pn_dim))
pn_ekk = Ekk / 24
print("harga jumlah persentase nya : " + str(pn_ekk))
pn_mil = Mil / 24
print("harga jumlah persentase nya : " + str(pn_mil))
pn_esk = Esk / 24
print("harga jumlah persentase nya : " + str(pn_esk))

print("")
import matplotlib.pyplot as plt
print("")
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
makanan = ["Burger","Pizza","Dimsum","Ekkado","Milkshake","Eskrim"]
jumlah = [25, 12, 16, 16, 8, 20 ]
ax.pie(jumlah, labels=makanan,autopct='%1.2f%%')
plt.title("Persentase keseluruhan")
plt.show()

print("")
print("[SOAL3]")
print("(Pesanan ahmad)")
Bur = 4
Piz = 2
uang_ahmad = 200000
hasil =(0.70 * ((Bur * 24000) + (Piz * 52000))) + (7.5 * 2000) - 5000
kem = uang_ahmad - hasil
print("maka total belanja ahmad adalah : Rp."+ str(hasil))
print("maka total kembalian ahmad adalah : Rp."+ str(kem))

print("(Pesanan beni)")
Dim = 3
Esk = 1 
Mil = 2
uang_beni = 150000
hasil =(0.70 * ((Dim * 30000) + (Esk * 15000)+ (Mil * 10000))) + (4 * 1800) - 5000
kemb = uang_beni - hasil
print("maka total belanja beni adalah : Rp."+ str(hasil))
print("maka total kembalian beni adalah : Rp."+ str(kemb))

print("(Pesanan citra)")
Esk = 3
uang_citra = 60000
hasil =(((Esk * 15000))) + (8 * 2000) - 5000
kemb = uang_citra - hasil
print("maka total belanja citra adalah : Rp."+ str(hasil))
print("maka total kembalian citra adalah : Rp."+ str(kemb))

print("(Pesanan dadang)")
Bur = 2
Dim = 1
uang_dadang = 100000
hasil =(0.80 * ((Bur * 24000) + (Dim * 30000))) + (5 * 1800) - 5000
kem = uang_dadang - hasil
print("maka total belanja dadang adalah : Rp."+ str(hasil))
print("maka total kembalian dadang adalah : Rp."+ str(kem))

print("(Pesanan epen)")
Ekk = 4
Esk = 1
Piz = 1
uang_epen = 200000
hasil =(0.70 * ((Ekk * 7500 ) + (Esk * 15000) + (Piz * 52000))) + (12 * 2200) - 5000
kem = uang_epen - hasil
print("maka total belanja epen adalah : Rp."+ str(hasil))
print("maka total kembalian epen adalah : Rp."+ str(kem))

print("")
print("[SOAL4]")

Bur = 4
Piz = 2
hasil =(0.30 * ((Bur * 24000) + (Piz * 52000)))  + 5000
print("maka jumlah potongan ahmad adalah : Rp."+ str(hasil))



Dim = 3
Esk = 1 
Mil = 2
hasil2 =(0.30 * ((Dim * 30000) + (Esk * 15000) + (Mil * 10000))) + 5000
kemb = uang_beni - hasil
print("maka jumlah potongan beni adalah : Rp."+ str(hasil2))

potongan_citra = 5000
print("maka jumlah potongan citra adalah : Rp."+ str(potongan_citra))

Bur = 2
Dim = 1
hasil3 =(0.20 * ((Bur * 24000) + (Dim * 30000))) + 5000
print("maka jumlah potongan dadang adalah : Rp."+ str(hasil3))

Ekk = 4
Esk = 1
Piz = 1
hasil4 =(0.30 * ((Ekk * 7500 ) + (Esk * 15000) + (Piz * 52000))) + 5000
print("maka jumlah potongan epen adalah : Rp."+ str(hasil4))

total = hasil + hasil2 + potongan_citra + hasil3 + hasil4
print("maka jumlah potongan total semua pembeli : Rp."+ str(total))

print("")
print("[SOAL5]")
jarak = 7.5
ongkir = 2000
jarak1 = 4
ongkir1 = 1800
jarak2 = 8
ongkir2 = 2000
jarak3 = 5
ongkir3 = 1800
jarak4 = 12
ongkir4 = 2200

hasil = (jarak * ongkir) + (jarak1 * ongkir1) + (jarak2 * ongkir2) + (jarak3 * ongkir3) + (jarak4 * ongkir4) 
print("maka semua pembeli adalah : Rp."+ str(hasil))
# Out:
# [SOAL1]
# total makanan yang dipesan : 24
# harga jumlah keseluruhan : 545000
#
# [SOAL2]
# harga jumlah persentase nya : 0.25
# harga jumlah persentase nya : 0.125
# harga jumlah persentase nya : 0.16666666666666666
# harga jumlah persentase nya : 0.16666666666666666
# harga jumlah persentase nya : 0.08333333333333333
# harga jumlah persentase nya : 0.20833333333333334
# [SOAL3]
# (Pesanan ahmad)
# maka total belanja ahmad adalah : Rp.150000.0
# maka total kembalian ahmad adalah : Rp.50000.0
# (Pesanan beni)
# maka total belanja beni adalah : Rp.89700.0
# maka total kembalian beni adalah : Rp.60300.0
# (Pesanan citra)
# maka total belanja citra adalah : Rp.56000
# maka total kembalian citra adalah : Rp.4000
# (Pesanan dadang)
# maka total belanja dadang adalah : Rp.66400.0
# maka total kembalian dadang adalah : Rp.33600.0
# (Pesanan epen)
# maka total belanja epen adalah : Rp.89300.0
# maka total kembalian epen adalah : Rp.110700.0
#
# [SOAL4]
# ...
