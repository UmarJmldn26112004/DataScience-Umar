# %%
beras	= 11400	
minyak = 	12700
ayam =	3400	
telur = 	21800	
popok	= 27000	
sabun_cuci = 	1800	
buah_anggur	= 3800	
roti_tawar	= 8500	
tissu =	6400	
mie_instan =	2200	
print("[SOAL1]")
print("belanjaan tia :")
beras_tia = 4
ayam_tia = 2
telur_tia = 3
sabun_cuci_tia = 5
buah_anggur_tia = 4
roti_tawar_tia = 2
mie_instan_tia = 12

diskon=85
jb_diskon_tia = (jb_tia / 100) * diskon
jb_tia = (beras_tia * beras) + (ayam_tia * (ayam * 10)) + (telur_tia * telur) + (sabun_cuci_tia * sabun_cuci) + (buah_anggur_tia * buah_anggur ) + (roti_tawar_tia * roti_tawar) + (mie_instan_tia * mie_instan)
print("maka jumlah belanjaan tia " + str(jb_tia) + " rupiah")
print("maka jumlah belanjaan tia setelah diskon " + str(jb_diskon_tia))

print("")
print("")
print("[SOAL2]")
print("belanjaan hana :")
minyak_hana = 2
ayam_hana = 5
telur_hana = 1.5
sabun_cuci_hana = 3
buah_anggur_hana = 8
roti_tawar_hana = 3
mie_instan_hana = 20
tissu_hana = 2


diskon=90
jb_diskon_hana = (jb_hana / 100) * diskon
jb_hana = (minyak_hana * minyak) + (ayam_hana * ayam ) + (telur_hana * telur ) + (sabun_cuci_hana * sabun_cuci) + (buah_anggur_hana * buah_anggur) + (roti_tawar_hana * roti_tawar) + (tissu_hana * tissu) + (mie_instan_hana * mie_instan)
print("maka jumlah belanjaan hana " + str(jb_hana))
print("maka jumlah belanjaan Hana setelah diskon " + str(jb_diskon_hana))

print("")
print("")
print("[SOAL3]")
print("belanjaan widia :")
beras_widia = 1
minyak_widia = 1
telur_widia = 1
buah_anggur_widia = 5
tissu_widia = 3
mie_instan_widia = 16


jb_widia = (beras_widia * beras) + (minyak_widia * minyak) + (telur_widia * telur) + (buah_anggur_widia * buah_anggur) + (tissu_widia * tissu) + (mie_instan_widia * mie_instan)
print("maka jumlah belanjaan widia " + str(jb_widia))


print("")
print("")
print("[SOAL4]")
print("belanjaan romi :")
minyak_romi = 3
telur_romi = 2
popok_romi = 4
sabun_cuci_romi = 8
mie_instan_romi = 8

diskon=85
jb_diskon_romi = (jb_romi / 100) * diskon
jb_romi = (minyak_romi * minyak) + (telur_romi * telur) + (popok_romi * popok) + (sabun_cuci_romi * sabun_cuci) + (mie_instan_romi * mie_instan)
print("maka jumlah belanjaan romi " + str(jb_romi))
print("maka jumlah belanjaan Romi setelah diskon " + str(jb_diskon_romi))

print("")
print("")
print("[SOAL5]")
print("belanjaan samsul :")
ayam_samsul = 3
telur_samsul = 4
popok_samsul = 2
buah_anggur_samsul = 7
tissu_samsul = 5
mie_instan_samsul = 10

diskon=75
jb_diskon_samsul = (jb_samsul / 100) * diskon
jb_samsul = (ayam_samsul * (ayam * 10)) + (telur_samsul * telur) + (popok_samsul * popok) + (buah_anggur_samsul * buah_anggur) + (tissu_samsul * tissu) + (mie_instan_samsul * mie_instan)
print("maka jumlah belanjaan samsul " + str(jb_samsul))
print("maka jumlah belanjaan Samsul setelah diskon " + str(jb_diskon_samsul))

print("")
print("")
print("[SOAL6]")
print("belanjaan Dimas :")
ayam_Dimas = 5
popok_Dimas = 5
buah_anggur_Dimas = 3
sabun_Dimas = 4
roti_tawar_Dimas = 5
mie_instan_Dimas = 6

diskon=75
jb_diskon_Dimas = (jb_Dimas / 100) * diskon
jb_Dimas = (ayam_Dimas * (ayam * 10)) + (popok_Dimas * popok)+ (buah_anggur_Dimas * buah_anggur) + (mie_instan_Dimas * mie_instan) + (roti_tawar_Dimas * roti_tawar) + (sabun_Dimas * sabun_cuci)
print("maka jumlah belanjaan Dimas " + str(jb_Dimas))
print("maka jumlah belanjaan Dimas setelah diskon " + str(jb_diskon_Dimas))
print("")
print("")

print("[SOAL7]")
max = [284475]
print("maka jumlah belanja paling besar setelah diskon adalah Dimas Rp." + str(max))
print("")
print("[SOAL8]")
terpersen = {"hana" : "Rp.173880"}
print("yang mwndapatkan diskon 10% adalah :" + str(terpersen))
# Out:
# [SOAL1]
# belanjaan tia :
# maka jumlah belanjaan tia 246600 rupiah
# maka jumlah belanjaan tia setelah diskon 209610.0
#
#
# [SOAL2]
# belanjaan hana :
# maka jumlah belanjaan hana 193200.0
# maka jumlah belanjaan Hana setelah diskon 173880.0
#
#
# [SOAL3]
# belanjaan widia :
# maka jumlah belanjaan widia 119300
#
#
# [SOAL4]
# belanjaan romi :
# maka jumlah belanjaan romi 221700
# maka jumlah belanjaan Romi setelah diskon 188445.0
#
#
# [SOAL5]
# belanjaan samsul :
# maka jumlah belanjaan samsul 323800
# maka jumlah belanjaan Samsul setelah diskon 242850.0
#
#
# [SOAL6]
# belanjaan Dimas :
# maka jumlah belanjaan Dimas 379300
# maka jumlah belanjaan Dimas setelah diskon 284475.0
#
#
# [SOAL7]
# maka jumlah belanja paling besar setelah diskon adalah Dimas Rp.[284475]
#
# [SOAL8]
# yang mwndapatkan diskon 10% adalah :{'hana': 'Rp.173880'}

# %%
import matplotlib.pyplot as plt

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
nama = ['tia','hana','widia','romi','samsul','dimas']
jumlah_belanja = [246600,193200,119300,221700,323800,379300]
c = ['blue','green','red']
plt.title("Data Jumlah Belanjaan")
plt.bar(nama, jumlah_belanja, color= c)
plt.show()

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
nama = ['tia','hana','widia','romi','samsul','dimas']
jumlah_belanja = [206610,173880,119300,188445,242850,284475]
c = ['blue','green','red']
plt.title("Data Jumlah Belanjaan Saat Diskon")
plt.bar(nama, jumlah_belanja, color= c)      
plt.show()

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
nama = ['tia','hana','widia','romi','samsul','dimas']
jumlah_belanja = [246600,193200,119300,221700,323800,379300]
ax.pie(jumlah_belanja, labels = nama, autopct= '%1.2f%%')
plt.title("Data Jumlah Belanjaan ")        
plt.show()

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
nama = ['tia','hana','widia','romi','samsul','dimas']
jumlah_belanja = [206610,173880,119300,188445,242850,284475]
ax.pie(jumlah_belanja, labels = nama, autopct= '%1.2f%%')
plt.title("Data Jumlah Belanjaan Diskon ")        
plt.show()
