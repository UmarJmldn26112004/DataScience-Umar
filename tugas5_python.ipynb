# %%
print("[SOAL1]")

kariawan = 20
asuransi = 75000
hasil= (kariawan * 300000) + (kariawan * asuransi)
print("maka total pengeluaran dari perusahaan A-Xis : Rp."+ str(hasil))

kariawan = 14
asuransi = 75000
hasil= (kariawan * 360000) + (kariawan * asuransi)
print("maka total pengeluaran dari perusahaan B-Log : Rp."+ str(hasil))

kariawan = 28
asuransi = 75000
hasil= (kariawan * 475000) + (kariawan * asuransi)
print("maka total pengeluaran dari perusahaan C-In : Rp."+ str(hasil))

kariawan = 42
asuransi = 75000
hasil= (kariawan * 580000) + (kariawan * asuransi)
print("maka total pengeluaran dari perusahaan D-Namic : Rp."+ str(hasil))

kariawan = 18
asuransi = 75000
hasil= (kariawan * 400000) + (kariawan * asuransi)
print("maka total pengeluaran dari perusahaan E-Psilon : Rp."+ str(hasil))

print("")
print("[SOAL2]")
pajak = 0.03
hutang_1= 0.08
hutang_2 = 0.04
hutang_3 = 0.12
hutang_4 = 0.11
hutang_5 = 0.03

laba_1 = 32500000
laba_2 = 31000000
laba_3 = 42000000
laba_4 = 51500000
laba_5 = 27000000

total = ( pajak *  laba_1) + (hutang_1 * 280000000)
print("maka total pajak dari perusahaan A-Axis adalah : Rp."+ str(total))

total = ( pajak *  laba_2) + (hutang_2 * 310000000)
print("maka total pajak dari perusahaan B-Log adalah : Rp."+ str(total))

total = ( pajak *  laba_3) + (hutang_3 * 420000000)
print("maka total pajak dari perusahaan C-In adalah : Rp."+ str(total))

total = ( pajak *  laba_4) + (hutang_4 * 550000000)
print("maka total pajak dari perusahaan D-Namic adalah : Rp."+ str(total))

total = ( pajak *  laba_5) + (hutang_5 * 340000000)
print("maka total pajak dari perusahaan E-Psilon adalah : Rp."+ str(total))

import matplotlib.pyplot as plt
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
perusahaan = ["A-Xis","B-Log","C-in","D-Namic","E-psilon"]
jumlah = [23375000,13330000,51660000,62045000,10100000]
c = ['blue', 'green', 'red', 'purple', 'yellow', 'black', 'brown']
plt.title("tabel pendapatan perusahaan")
plt.bar(perusahaan, jumlah, color = c)
plt.show()

fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
perusahaan = ["A-Xis","B-Log","C-in","D-Namic","E-psilon"]
jumlah = [23375000,13330000,51660000,62045000,10100000]
ax.pie(jumlah, labels=perusahaan,autopct='%1.2f%%')
plt.title("tabel pendapatan perusahaan")
plt.show()

print("")
print("[SOAL3]")
aset1 = 280000000
aset2 = 310000000
aset3 = 420000000
aset4 = 550000000
aset5 = 340000000

csr = 0.025
csr2 = 0.035

hasil = aset1 * csr
print("maka csr perusahan A-Axis adalah : Rp."+str(hasil))
hasil = aset2 * csr2
print("maka csr perusahan B-Log adalah : Rp."+str(hasil))
hasil = aset3 * csr2
print("maka csr perusahan C-In adalah : Rp."+str(hasil))
hasil = aset4 * csr2
print("maka csr perusahan D-Namic adalah : Rp."+str(hasil))
hasil = aset5 * csr2
print("maka csr perusahan E-Psilon adalah : Rp."+str(hasil))

fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
perusahaan = ["A-Xis","B-Log","C-in","D-Namic","E-psilon"]
jumlah = [7000000.0,10850000.000000002,14700000.000000002,19250000.0,11900000.000000002]
c = ['blue', 'green', 'red', 'purple', 'yellow', 'black', 'brown']
plt.title("tabel csr perusahaan")
plt.bar(perusahaan, jumlah, color = c)
plt.show()

fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
perusahaan = ["A-Xis","B-Log","C-in","D-Namic","E-psilon"]
jumlah = [7000000.0,10850000.000000002,14700000.000000002,19250000.0,11900000.000000002]
ax.pie(jumlah, labels=perusahaan,autopct='%1.2f%%')
plt.title("tabel csr perusahaan")
plt.show()
print("")

print("[SOAL4]")
laba_1 = 32500000
laba_2 = 31000000
laba_3 = 42000000
laba_4 = 51500000
laba_5 = 27000000

hasil = laba_1 * 12
print("laba : Rp."+str(hasil))
hasil2 = laba_2 * 12
print("laba : Rp."+str(hasil2))
hasil3 = laba_3 * 12
print("laba : Rp."+str(hasil3))
hasil4 = laba_4 * 12
print("laba : Rp."+str(hasil4))
hasil5 = laba_5 * 12
print("laba : Rp."+str(hasil5))
total = hasil + hasil2 + hasil3 + hasil4 + hasil5
print("total laba perusahaan selama 1 tahun adalah : Rp."+str(total))

print("")
print("[SOAL5]")
laba = 32500000
labaA = 31000000
labaB = 42000000
labaC = 51500000
labaD = 27000000

gaji = 300000
gajiA = 360000
gajiB = 475000
gajiC = 580000
gajiD = 400000

kariawa = 20
kariawaA = 14
kariawaB = 28
kariawaC = 42
kariawaD = 18
csr = 0.025
csr2 = 0.035
hasil =(laba * 12) -csr * 280000000 - (7500000 * 12) - 23375000
print("total pendapatan bersih 1 tahun perusahaan A-Axis : Rp."+str(hasil))

hasil =(labaA * 12) -csr2 * 310000000 - (6090000 * 12) - 13330000
print("total pendapatan bersih 1 tahun perusahaan B-Log : Rp."+str(hasil))

hasil =(labaB * 12) -csr2 * 420000000 - (15400000 * 12) - 51660000
print("total pendapatan bersih 1 tahun perusahaan C-In : Rp."+str(hasil))

hasil =(labaC * 12) -csr2 * 550000000 - (27510000 * 12) - 62045000
print("total pendapatan bersih 1 tahun perusahaan D-Namis : Rp."+str(hasil))

hasil =(labaD * 12) -csr2 * 340000000 - (8550000 * 12) - 11010000
print("total pendapatan bersih 1 tahun perusahaan E-Psilon : Rp."+str(hasil))

fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
perusahaan = ["A-Xis","B-Log","C-in","D-Namic","E-psilon"]
jumlah = [269625000,274740000,252840000,206585000,198490000]
c = ['blue', 'green', 'red', 'purple', 'yellow', 'black', 'brown']
plt.title("tabel pendapatan bersih 1 tahun perusahaan")
plt.bar(perusahaan, jumlah, color = c)
plt.show()

fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
perusahaan = ["A-Xis","B-Log","C-in","D-Namic","E-psilon"]
jumlah = [269625000,274740000,252840000,206585000,198490000]
ax.pie(jumlah, labels=perusahaan,autopct='%1.2f%%')
plt.title("tabel pendapatan bersih 1 tahun perusahaan")
plt.show()
# Out:
# [SOAL1]
# maka total pengeluaran dari perusahaan A-Xis : Rp.7500000
# maka total pengeluaran dari perusahaan B-Log : Rp.6090000
# maka total pengeluaran dari perusahaan C-In : Rp.15400000
# maka total pengeluaran dari perusahaan D-Namic : Rp.27510000
# maka total pengeluaran dari perusahaan E-Psilon : Rp.8550000
#
# [SOAL2]
# maka total pajak dari perusahaan A-Axis adalah : Rp.23375000.0
# maka total pajak dari perusahaan B-Log adalah : Rp.13330000.0
# maka total pajak dari perusahaan C-In adalah : Rp.51660000.0
# maka total pajak dari perusahaan D-Namic adalah : Rp.62045000.0
# maka total pajak dari perusahaan E-Psilon adalah : Rp.11010000.0
# [SOAL3]
# maka csr perusahan A-Axis adalah : Rp.7000000.0
# maka csr perusahan B-Log adalah : Rp.10850000.000000002
# maka csr perusahan C-In adalah : Rp.14700000.000000002
# maka csr perusahan D-Namic adalah : Rp.19250000.0
# maka csr perusahan E-Psilon adalah : Rp.11900000.000000002
# [SOAL4]
# laba : Rp.390000000
# laba : Rp.372000000
# ...
