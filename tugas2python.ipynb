# %%
print("soal1")
s2_a = 0
s2_b = 1
s2_c = 4
s2_d = 7
s2_e = 5
s2_f = 0
print("Tamat s2")
jumlah_s2 = s2_a + s2_b + s2_c + s2_d + s2_e + s2_f
print("maka hasilnya :" + str(jumlah_s2)) 

print("")
s1_a = 4
s1_b = 12
s1_c = 6
s1_d = 13
s1_e = 14
s1_f = 0
print("Tamat s1")
jumlah_s1 = s1_a + s1_b + s1_c + s1_d + s1_e + s1_f
print("maka hasilnya :" + str(jumlah_s1)) 

print("")
sma_a = 12
sma_b = 17
sma_c = 5
sma_d = 20
sma_e = 11
sma_f = 75
print("Tamat SMA")
jumlah_sma = sma_a + sma_b + sma_c + sma_d + sma_e + sma_f
print("maka hasilnya :" + str(jumlah_sma)) 

print("")
smp_a = 5
smp_b = 6
smp_c = 15
smp_d = 9
smp_e = 20
smp_f = 15
print("Tamat SMP")
jumlah_smp = smp_a + smp_b + smp_c + smp_d + smp_e + smp_f
print("maka hasilnya :" + str(jumlah_smp))

print("")
sd_a = 1
sd_b = 8
sd_c = 0
sd_d = 19
sd_e = 10
sd_f = 1
print("Tamat SD")
jumlah_sd = sd_a + sd_b + sd_c + sd_d + sd_e + sd_f
print("maka hasilnya :" + str(jumlah_sd))

print("")
tdk_dkt_a = 2
tdk_dkt_b = 14
tdk_dkt_c = 3
tdk_dkt_d = 10
tdk_dkt_e = 0
tdk_dkt_f = 1
print("Tidak diketahui")
jumlah_tdk_dkt = tdk_dkt_a + tdk_dkt_b + tdk_dkt_c + tdk_dkt_d + tdk_dkt_e + tdk_dkt_f
print("maka hasilnya :" + str(jumlah_tdk_dkt))

print("")
print("soal2")
index = 25
b_index = (jumlah_s2 / 100) * index
print("maka hasilnya " + str(b_index))

print("")
index = 20
b_index = (jumlah_s1 / 100) * index
print("maka hasilnya " + str(b_index))

print("")
index = 15
b_index = (jumlah_sma / 100) * index
print("maka hasilnya " + str(b_index))

print("")
index = 10
b_index = (jumlah_smp / 100) * index
print("maka hasilnya " + str(b_index))\

print("")
index = 5
b_index = (jumlah_sd / 100) * index
print("maka hasilnya " + str(b_index))

print("")
index = 3
b_index = (jumlah_tdk_dkt / 100) * index
print("maka hasilnya " + str(b_index))

print("")
print("soal3")
print("")
b_index = 25
bb_index = (0 / 100) * b_index
print("maka bobot index mutu dari rentan usia >70 s2 :" + str(bb_index))
print("")
b_index = 20
bb_index = (4 / 100) * b_index
print("maka bobot index mutu dari rentan usia >70 s1 :" + str(bb_index))
print("")
b_index = 15
bb_index = (12 / 100) * b_index
print("maka bobot index mutu dari rentan usia >70 sma :" + str(bb_index))
print("")
b_index = 10
bb_index = (5 / 100) * b_index
print("maka bobot index mutu dari rentan usia >70 smp :" + str(bb_index))
print("")
b_index = 5
bb_index = (1 / 100) * b_index
print("maka bobot index mutu dari rentan usia >70 sd :" + str(bb_index))
print("")
b_index = 3
bb_index = (2 / 100) * b_index
print("maka bobot index mutu dari rentan usia >70 Tidak diketahui :" + str(bb_index))

print("")
print("")
b_index = 25
bb_index = (1 / 100) * b_index
print("maka bobot index mutu dari rentan usia >60 s2 :" + str(bb_index))
print("")
b_index = 20
bb_index = (12 / 100) * b_index
print("maka bobot index mutu dari rentan usia >60 s1 :" + str(bb_index))
print("")
b_index = 15
bb_index = (17 / 100) * b_index
print("maka bobot index mutu dari rentan usia >60 sma :" + str(bb_index))
print("")
b_index = 10
bb_index = (6 / 100) * b_index
print("maka bobot index mutu dari rentan usia >60 smp :" + str(bb_index))
print("")
b_index = 5
bb_index = (8 / 100) * b_index
print("maka bobot index mutu dari rentan usia >60 sd :" + str(bb_index))
print("")
b_index = 3
bb_index = (14 / 100) * b_index
print("maka bobot index mutu dari rentan usia >60 Tidak diketahui :" + str(bb_index))

print("")
print("")
b_index = 25
bb_index = (4 / 100) * b_index
print("maka bobot index mutu dari rentan usia >50 s2 :" + str(bb_index))
print("")
b_index = 20
bb_index = (6 / 100) * b_index
print("maka bobot index mutu dari rentan usia >50 s1 :" + str(bb_index))
print("")
b_index = 15
bb_index = (5 / 100) * b_index
print("maka bobot index mutu dari rentan usia >50 sma :" + str(bb_index))
print("")
b_index = 10
bb_index = (15 / 100) * b_index
print("maka bobot index mutu dari rentan usia >50 smp :" + str(bb_index))
print("")
b_index = 5
bb_index = (0 / 100) * b_index
print("maka bobot index mutu dari rentan usia >50 sd :" + str(bb_index))
print("")
b_index = 3
bb_index = (3 / 100) * b_index
print("maka bobot index mutu dari rentan usia >50 Tidak diketahui :" + str(bb_index))

print("")
print("")
b_index = 25
bb_index = (7 / 100) * b_index
print("maka bobot index mutu dari rentan usia >40 s2 :" + str(bb_index))
print("")
b_index = 20
bb_index = (13 / 100) * b_index
print("maka bobot index mutu dari rentan usia >40 s1 :" + str(bb_index))
print("")
b_index = 15
bb_index = (20 / 100) * b_index
print("maka bobot index mutu dari rentan usia >40 sma :" + str(bb_index))
print("")
b_index = 10
bb_index = (9 / 100) * b_index
print("maka bobot index mutu dari rentan usia >40 smp :" + str(bb_index))
print("")
b_index = 5
bb_index = (19 / 100) * b_index
print("maka bobot index mutu dari rentan usia >40 sd :" + str(bb_index))
print("")
b_index = 3
bb_index = (10 / 100) * b_index
print("maka bobot index mutu dari rentan usia >40 Tidak diketahui :" + str(bb_index))

print("")
print("")
b_index = 25
bb_index = (5 / 100) * b_index
print("maka bobot index mutu dari rentan usia >30 s2 :" + str(bb_index))
print("")
b_index = 20
bb_index = (14 / 100) * b_index
print("maka bobot index mutu dari rentan usia >30 s1 :" + str(bb_index))
print("")
b_index = 15
bb_index = (11 / 100) * b_index
print("maka bobot index mutu dari rentan usia >30 sma :" + str(bb_index))
print("")
b_index = 10
bb_index = (20 / 100) * b_index
print("maka bobot index mutu dari rentan usia >30 smp :" + str(bb_index))
print("")
b_index = 5
bb_index = (10 / 100) * b_index
print("maka bobot index mutu dari rentan usia >30 sd :" + str(bb_index))
print("")
b_index = 3
bb_index = (0 / 100) * b_index
print("maka bobot index mutu dari rentan usia >30 Tidak diketahui :" + str(bb_index))

print("")
print("")
b_index = 25
bb_index = (0 / 100) * b_index
print("maka bobot index mutu dari rentan usia >20 s2 :" + str(bb_index))
print("")
b_index = 20
bb_index = (0 / 100) * b_index
print("maka bobot index mutu dari rentan usia >20 s1 :" + str(bb_index))
print("")
b_index = 15
bb_index = (75 / 100) * b_index
print("maka bobot index mutu dari rentan usia >20 sma :" + str(bb_index))
print("")
b_index = 10
bb_index = (15 / 100) * b_index
print("maka bobot index mutu dari rentan usia >20 smp :" + str(bb_index))
print("")
b_index = 5
bb_index = (1 / 100) * b_index
print("maka bobot index mutu dari rentan usia >20 sd :" + str(bb_index))
print("")
b_index = 3
bb_index = (1 / 100) * b_index
print("maka bobot index mutu dari rentan usia >20 Tidak diketahui :" + str(bb_index))
print("")
print("soal4")
min = [3.2099999]
print("maka usia dengan index  mutu pendidikan paling kecil adalah usia >70 :" +str(min))
# Out:
# soal1
# Tamat s2
# maka hasilnya :17
#
# Tamat s1
# maka hasilnya :49
#
# Tamat SMA
# maka hasilnya :140
#
# Tamat SMP
# maka hasilnya :70
#
# Tamat SD
# maka hasilnya :39
#
# Tidak diketahui
# maka hasilnya :30
#
# soal2
# maka hasilnya 4.25
#
# maka hasilnya 9.8
#
# maka hasilnya 21.0
#
# maka hasilnya 7.0
#
# maka hasilnya 1.9500000000000002
#
# maka hasilnya 0.8999999999999999
#
# soal3
#
# maka bobot index mutu dari rentan usia >70 s2 :0.0
#
# maka bobot index mutu dari rentan usia >70 s1 :0.8
#
# maka bobot index mutu dari rentan usia >70 sma :1.7999999999999998
#
# maka bobot index mutu dari rentan usia >70 smp :0.5
#
# maka bobot index mutu dari rentan usia >70 sd :0.05
#
# maka bobot index mutu dari rentan usia >70 Tidak diketahui :0.06
#
#
# maka bobot index mutu dari rentan usia >60 s2 :0.25
#
# maka bobot index mutu dari rentan usia >60 s1 :2.4
#
# maka bobot index mutu dari rentan usia >60 sma :2.5500000000000003
#
# maka bobot index mutu dari rentan usia >60 smp :0.6
#
# ...

# %%
import matplotlib.pyplot as plt

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
pendidikan = ['S2','S1','SMA','SMP','SD','Tidak diketahui']
orang = [17,49,140,70,39,40]
c = ['blue']
plt.title("Sensus Penduduk Kecamatan Samarang")
plt.bar(pendidikan, orang, color= c)
plt.show()

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
pendidikan = ['S2','S1','SMA','SMP','SD','Tidak diketahui']               
orang = [17,49,140,70,39,40]
ax.pie(orang, labels = pendidikan, autopct= '%1.2f%%')
plt.title("Sensus Penduduk Kecamatan Samarang")        
plt.show()

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
usia = ['>70','>60','>50','>40','>30','>20']
angka = [24,58,33,78,60,92]
c = ['blue']
plt.title("Sensus Penduduk Kecamatan Samarang")
plt.bar(usia, angka, color= c)
plt.show()

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
usia = ['>70','>60','>50','>40','>30','>20']
angka = [24,58,33,78,60,92]
ax.pie(angka, labels = usia, autopct= '%1.2f%%')
plt.title("Sensus Penduduk Kecamatan Samarang")        
plt.show()
